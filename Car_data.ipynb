# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('car data.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
print(df['Seller_Type'].unique())
# Out:
# ['Dealer' 'Individual']

# %%
print(df['Transmission'].unique())
# Out:
# ['Manual' 'Automatic']

# %%
print(df['Owner'].unique())
# Out:
# [0 1 3]

# %%
print([df[lst].unique() for lst in col])
# Out:
# [array(['Dealer', 'Individual'], dtype=object), array(['Manual', 'Automatic'], dtype=object), array([0, 1, 3], dtype=int64)]

# %%
col=['Seller_Type','Transmission','Owner']

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.drop(['Car_Name'],axis=1,inplace=True)

# %%
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
df['Current_Year']=2020

# %%
df['no_of_years']=df['Current_Year']-df['Year']

# %%
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Current_Year=  Current_Year  no_of_years
# ...

# %%
df.drop(['Year'],axis=1,inplace=True)

# %%
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Current_Year=  Current_Year  no_of_years
# 0         Manual      0           2020          2020            6
# ...

# %%
df.drop(['Current_Year'],axis=1,inplace=True)

# %%
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Current_Year=  Current_Year  no_of_years
# 0         Manual      0           2020          2020            6
# ...

# %%
pd.get_dummies(df)
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Current_Year=  \
# 0             3.35           5.59       27000      0           2020
# 1             4.75           9.54       43000      0           2020
# 2             7.25           9.85        6900      0           2020
# 3             2.85           4.15        5200      0           2020
# 4             4.60           6.87       42450      0           2020
# ..             ...            ...         ...    ...            ...
# 296           9.50          11.60       33988      0           2020
# 297           4.00           5.90       60000      0           2020
# 298           3.35          11.00       87934      0           2020
# 299          11.50          12.50        9000      0           2020
# 300           5.30           5.90        5464      0           2020
#
#      Current_Year  no_of_years  Fuel_Type_CNG  Fuel_Type_Diesel  \
# 0            2020            6              0                 0
# ...

# %%
df.drop(['Current_Year='],axis=1,inplace=True)

# %%
final_df=pd.get_dummies(df,drop_first=True)

# %%
final_df
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  no_of_years  \
# 0             3.35           5.59       27000      0            6
# 1             4.75           9.54       43000      0            7
# 2             7.25           9.85        6900      0            3
# 3             2.85           4.15        5200      0            9
# 4             4.60           6.87       42450      0            6
# ..             ...            ...         ...    ...          ...
# 296           9.50          11.60       33988      0            4
# 297           4.00           5.90       60000      0            5
# 298           3.35          11.00       87934      0           11
# 299          11.50          12.50        9000      0            3
# 300           5.30           5.90        5464      0            4
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                   0                 1                       0
# ...

# %%
import seaborn as sns
sns.heatmap(final_df.corr(),annot=True)

# %%
sns.pairplot(final_df)

# %%
X=final_df.drop(['Selling_Price'],axis=1)

# %%
X=X.iloc[:,:]

# %%
X
# Out:
#      Present_Price  Kms_Driven  Owner  no_of_years  Fuel_Type_Diesel  \
# 0             5.59       27000      0            6                 0
# 1             9.54       43000      0            7                 1
# 2             9.85        6900      0            3                 0
# 3             4.15        5200      0            9                 0
# 4             6.87       42450      0            6                 1
# ..             ...         ...    ...          ...               ...
# 296          11.60       33988      0            4                 1
# 297           5.90       60000      0            5                 0
# 298          11.00       87934      0           11                 0
# 299          12.50        9000      0            3                 1
# 300           5.90        5464      0            4                 0
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                   1                       0                    1
# ...

# %%
y=final_df['Selling_Price']

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
#Feature importance
from sklearn.ensemble import ExtraTreesRegressor

# %%
model=ExtraTreesRegressor()

# %%
model.fit(X,y)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)

# %%
model.feature_importances_
# Out:
# array([3.79002334e-01, 4.48789934e-02, 3.10992006e-04, 7.35510128e-02,
#        2.12428343e-01, 1.34829204e-02, 1.34269995e-01, 1.42075409e-01])

# %%
X.columns
# Out:
# Index(['Present_Price', 'Kms_Driven', 'Owner', 'no_of_years',
#        'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Seller_Type_Individual',
#        'Transmission_Manual'],
#       dtype='object')

# %%
feature_importance=pd.Series(model.feature_importances_,index=X.columns)

# %%
feature_importance.nlargest(5).plot(kind='barh')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train
# Out:
#      Present_Price  Kms_Driven  Owner  no_of_years  Fuel_Type_Diesel  \
# 74            8.93       83000      0            6                 1
# 239           4.43       23709      0            8                 0
# 64           36.23        6000      0            3                 1
# 294           6.80       33019      0            6                 0
# 286           7.90       28569      0            4                 0
# ..             ...         ...    ...          ...               ...
# 251           9.90       56701      0            7                 0
# 192           0.75       49000      1           13                 0
# 117           1.90       14000      0            5                 0
# 47            4.15       65000      0           14                 0
# 172           0.64       13700      0            6                 0
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 74                  0                       0                    1
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_random=RandomForestRegressor()

# %%
#Hyperparameters
n_estimators=[int(i) for i in np.linspace(100,1200,12)]

# %%
n_estimators
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
max_features=['auto','sqrt']
max_depth=[ int(x) for x in  np.linspace(5,30,6)]
min_samples_split=[2,5,10,15,100]
min_samples_leaf=[1,2,5,10]

# %%
random_grid={
    'n_estimators':n_estimators,
    'max_depth':max_depth,
    'max_features':max_features,
    'min_samples_leaf':min_samples_leaf,
    'min_samples_split':min_samples_split
        
}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
rf=RandomForestRegressor()

# %%
model=RandomizedSearchCV(rf,random_grid,scoring='neg_mean_squared_error',n_iter=10,cv=5,random_state=0,verbose=True)

# %%
model.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:   37.8s finished
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
# ...

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([ 6.85736667,  0.50519988,  4.77395089,  8.84206766, 14.48193275,
#         5.23398929,  3.24336307,  0.45563851,  3.99905378,  4.89462781,
#         2.82990962,  0.73671075,  4.89654196,  7.02543877,  7.65064204,
#        14.42660266,  6.66876542,  3.99442857,  0.46148976,  1.51927877,
#         3.13708353,  5.00321369,  5.39967037, 10.02374143,  0.18565157,
#         0.75796224,  0.32024355,  0.66181055,  0.47939665,  4.11734095,
#         2.5926594 ,  5.94196442,  0.50617936,  7.34352037,  3.28060502,
#         1.14890743,  5.87087187,  5.38029978,  0.22765143,  7.98011675,
#         8.08597191, 23.58809425,  4.93972976,  4.37996117,  5.74362712,
#        10.92077849,  0.25370323,  0.79473452,  5.43055704,  6.5889776 ,
#         6.78143299,  3.09873135,  5.35088413, 24.81948234,  1.17439937,
#         1.13458094,  0.45726478,  2.51493709,  3.52758295,  2.57377881,
#         3.75612075])

# %%
sns.distplot(y_test-y_pred)

# %%
import pickle

# %%
file=open('randomForest_pickle.pkl','wb')
pickle.dump(model,file)
